# %%
import pandas as pd

# %%
df_20a_26a_cc = pd.read_csv('confirmed cases from Apr 20th to Apr 26th.csv')

# %%
df_20a_26a_cc.head()
# Out:
#    Patient Number State Patient Number Date Announced  Estimated Onset Date  \
# 0         17307.0                  NaN     20/04/2020                   NaN
# 1         17308.0                  NaN     20/04/2020                   NaN
# 2         17309.0                  NaN     20/04/2020                   NaN
# 3         17310.0                  NaN     20/04/2020                   NaN
# 4         17311.0                  NaN     20/04/2020                   NaN
#
#    Age Bracket Gender Detected City Detected District Detected State  \
# 0         48.0      M           NaN           Bhadrak         Odisha
# 1         55.0      M           NaN           Bhadrak         Odisha
# 2         57.0      M           NaN           Bhadrak         Odisha
# 3         58.0      M           NaN           Bhadrak         Odisha
# 4         66.0      M           NaN           Bhadrak         Odisha
#
#   State code  ...            Notes Contracted from which Patient (Suspected)  \
# ...

# %%
df_20a_26a_cc.describe()
# Out:
#        Patient Number  Estimated Onset Date  Age Bracket  Backup Notes  \
# count    10585.000000                   0.0   676.000000           0.0
# mean     22599.000000                   NaN    35.619379           NaN
# std       3055.770634                   NaN    17.191295           NaN
# min      17307.000000                   NaN     0.300000           NaN
# 25%      19953.000000                   NaN    23.000000           NaN
# 50%      22599.000000                   NaN    33.500000           NaN
# 75%      25245.000000                   NaN    47.000000           NaN
# max      27891.000000                   NaN    98.000000           NaN
#
#           Num cases
# count  10819.000000
# mean       0.978371
# std       14.024517
# min     -602.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max      602.000000

# %%
df_20a_26a_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10819 entries, 0 to 10818
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Patient Number                             10585 non-null  float64
#  1   State Patient Number                       540 non-null    object
#  2   Date Announced                             10819 non-null  object
#  3   Estimated Onset Date                       0 non-null      float64
#  4   Age Bracket                                676 non-null    float64
#  5   Gender                                     1567 non-null   object
#  6   Detected City                              184 non-null    object
#  7   Detected District                          6220 non-null   object
#  8   Detected State                             10819 non-null  object
#  9   State code                                 10819 non-null  object
# ...

# %%
df_20a_26a_cc.isnull().sum()
# Out:
# Patient Number                                 234
# State Patient Number                         10279
# Date Announced                                   0
# Estimated Onset Date                         10819
# Age Bracket                                  10143
# Gender                                        9252
# Detected City                                10635
# Detected District                             4599
# Detected State                                   0
# State code                                       0
# Current Status                                   0
# Notes                                           18
# Contracted from which Patient (Suspected)    10718
# Nationality                                   9664
# Type of transmission                         10780
# Status Change Date                             234
# Source_1                                       387
# Source_2                                     10342
# ...

# %%
df_20a_26a_cc = df_20a_26a_cc[['Patient Number', 'Date Announced', 'Estimated Onset Date', 'Age Bracket', 'Gender', 'Detected District', 'Detected State', 'State code', 'Status Change Date']]

# %%
df_20a_26a_cc.head()
# Out:
#    Patient Number Date Announced  Estimated Onset Date  Age Bracket Gender  \
# 0         17307.0     20/04/2020                   NaN         48.0      M
# 1         17308.0     20/04/2020                   NaN         55.0      M
# 2         17309.0     20/04/2020                   NaN         57.0      M
# 3         17310.0     20/04/2020                   NaN         58.0      M
# 4         17311.0     20/04/2020                   NaN         66.0      M
#
#   Detected District Detected State State code Status Change Date
# 0           Bhadrak         Odisha         OR         20/04/2020
# 1           Bhadrak         Odisha         OR         20/04/2020
# 2           Bhadrak         Odisha         OR         20/04/2020
# 3           Bhadrak         Odisha         OR         20/04/2020
# 4           Bhadrak         Odisha         OR         20/04/2020

# %%
df_i_19a_cc = pd.read_csv('confirmed cases till Apr 19th.csv')

# %%
df_i_19a_cc.head()
# Out:
#    Patient Number State Patient Number Date Announced  Estimated Onset Date  \
# 0             1.0             KL-TS-P1     30/01/2020                   NaN
# 1             2.0             KL-AL-P1     02/02/2020                   NaN
# 2             3.0             KL-KS-P1     03/02/2020                   NaN
# 3             4.0                DL-P1     02/03/2020                   NaN
# 4             5.0                TS-P1     02/03/2020                   NaN
#
#   Age Bracket Gender             Detected City Detected District  \
# 0          20      F                  Thrissur          Thrissur
# 1         NaN    NaN                 Alappuzha         Alappuzha
# 2         NaN    NaN                 Kasaragod         Kasaragod
# 3          45      M  East Delhi (Mayur Vihar)        East Delhi
# 4          24      M                 Hyderabad         Hyderabad
#
#   Detected State State code  ...  \
# 0         Kerala         KL  ...
# 1         Kerala         KL  ...
# ...

# %%
df_i_19a_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17364 entries, 0 to 17363
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Patient Number                             17306 non-null  float64
#  1   State Patient Number                       2457 non-null   object
#  2   Date Announced                             17364 non-null  object
#  3   Estimated Onset Date                       0 non-null      float64
#  4   Age Bracket                                1670 non-null   object
#  5   Gender                                     3746 non-null   object
#  6   Detected City                              2166 non-null   object
#  7   Detected District                          14978 non-null  object
#  8   Detected State                             17363 non-null  object
#  9   State code                                 17363 non-null  object
# ...

# %%
df_i_19a_cc = df_i_19a_cc[['Patient Number', 'Date Announced', 'Estimated Onset Date', 'Age Bracket', 'Gender', 'Detected District', 'Detected State', 'State code', 'Status Change Date']]

# %%
df_i_19a_cc.head()
# Out:
#    Patient Number Date Announced  Estimated Onset Date Age Bracket Gender  \
# 0             1.0     30/01/2020                   NaN          20      F
# 1             2.0     02/02/2020                   NaN         NaN    NaN
# 2             3.0     03/02/2020                   NaN         NaN    NaN
# 3             4.0     02/03/2020                   NaN          45      M
# 4             5.0     02/03/2020                   NaN          24      M
#
#   Detected District Detected State State code Status Change Date
# 0          Thrissur         Kerala         KL         14/02/2020
# 1         Alappuzha         Kerala         KL         14/02/2020
# 2         Kasaragod         Kerala         KL         14/02/2020
# 3        East Delhi          Delhi         DL         15/03/2020
# 4         Hyderabad      Telangana         TG         02/03/2020

# %%
frames = [df_i_19a_cc, df_20a_26a_cc]

# %%
df_i_26a_cc = pd.concat(frames)

# %%
df_i_26a_cc.head()
# Out:
#    Patient Number Date Announced  Estimated Onset Date Age Bracket Gender  \
# 0             1.0     30/01/2020                   NaN          20      F
# 1             2.0     02/02/2020                   NaN         NaN    NaN
# 2             3.0     03/02/2020                   NaN         NaN    NaN
# 3             4.0     02/03/2020                   NaN          45      M
# 4             5.0     02/03/2020                   NaN          24      M
#
#   Detected District Detected State State code Status Change Date
# 0          Thrissur         Kerala         KL         14/02/2020
# 1         Alappuzha         Kerala         KL         14/02/2020
# 2         Kasaragod         Kerala         KL         14/02/2020
# 3        East Delhi          Delhi         DL         15/03/2020
# 4         Hyderabad      Telangana         TG         02/03/2020

# %%
df_i_26a_cc.head()
# Out:
#    Patient Number Date Announced  Estimated Onset Date Age Bracket Gender  \
# 0             1.0     30/01/2020                   NaN          20      F
# 1             2.0     02/02/2020                   NaN         NaN    NaN
# 2             3.0     03/02/2020                   NaN         NaN    NaN
# 3             4.0     02/03/2020                   NaN          45      M
# 4             5.0     02/03/2020                   NaN          24      M
#
#   Detected District Detected State State code Status Change Date
# 0          Thrissur         Kerala         KL         14/02/2020
# 1         Alappuzha         Kerala         KL         14/02/2020
# 2         Kasaragod         Kerala         KL         14/02/2020
# 3        East Delhi          Delhi         DL         15/03/2020
# 4         Hyderabad      Telangana         TG         02/03/2020

# %%
df_i_26a_cc = df_i_26a_cc.reset_index()

# %%
df_i_26a_cc = df_i_26a_cc.drop(['index'], axis=1)

# %%
df_i_26a_cc.head()
# Out:
#    Patient Number Date Announced  Estimated Onset Date Age Bracket Gender  \
# 0             1.0     30/01/2020                   NaN          20      F
# 1             2.0     02/02/2020                   NaN         NaN    NaN
# 2             3.0     03/02/2020                   NaN         NaN    NaN
# 3             4.0     02/03/2020                   NaN          45      M
# 4             5.0     02/03/2020                   NaN          24      M
#
#   Detected District Detected State State code Status Change Date
# 0          Thrissur         Kerala         KL         14/02/2020
# 1         Alappuzha         Kerala         KL         14/02/2020
# 2         Kasaragod         Kerala         KL         14/02/2020
# 3        East Delhi          Delhi         DL         15/03/2020
# 4         Hyderabad      Telangana         TG         02/03/2020

# %%
df_i_26a_cc = df_i_26a_cc.drop(['Estimated Onset Date'], axis=1)

# %%
df_i_26a_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28183 entries, 0 to 28182
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient Number      27891 non-null  float64
#  1   Date Announced      28183 non-null  object
#  2   Age Bracket         2346 non-null   object
#  3   Gender              5313 non-null   object
#  4   Detected District   21198 non-null  object
#  5   Detected State      28182 non-null  object
#  6   State code          28182 non-null  object
#  7   Status Change Date  27780 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 1.7+ MB

# %%
df_i_26a_cc.head()
# Out:
#    Patient Number Date Announced Age Bracket Gender Detected District  \
# 0             1.0     30/01/2020          20      F          Thrissur
# 1             2.0     02/02/2020         NaN    NaN         Alappuzha
# 2             3.0     03/02/2020         NaN    NaN         Kasaragod
# 3             4.0     02/03/2020          45      M        East Delhi
# 4             5.0     02/03/2020          24      M         Hyderabad
#
#   Detected State State code Status Change Date
# 0         Kerala         KL         14/02/2020
# 1         Kerala         KL         14/02/2020
# 2         Kerala         KL         14/02/2020
# 3          Delhi         DL         15/03/2020
# 4      Telangana         TG         02/03/2020

# %%
df_i_26a_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28183 entries, 0 to 28182
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient Number      27891 non-null  float64
#  1   Date Announced      28183 non-null  object
#  2   Age Bracket         2346 non-null   object
#  3   Gender              5313 non-null   object
#  4   Detected District   21198 non-null  object
#  5   Detected State      28182 non-null  object
#  6   State code          28182 non-null  object
#  7   Status Change Date  27780 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 1.7+ MB

# %%
df_i_26a_rd = pd.read_csv('death_and_recovered1 + death_and_recovered2 & frozen as of Apr 26th.csv')

# %%
df_i_26a_rd.head()
# Out:
#    Sl_No        Date  Age Bracket Gender Patient_Status City District  \
# 0     59  13/03/2020          NaN    NaN       Deceased  NaN      NaN
# 1     54  20/03/2020          NaN    NaN      Recovered  NaN      NaN
# 2     55  24/03/2020          NaN    NaN      Recovered  NaN      NaN
# 3     56  24/03/2020          NaN    NaN      Recovered  NaN      NaN
# 4     60  26/03/2020          NaN    NaN       Deceased  NaN      NaN
#
#        State Statecode   Notes Nationality                   Source_1  \
# 0  Karnataka        KA   KA-P6         NaN  Opening Data as of Mar 29
# 1  Karnataka        KA   KA-P5         NaN  Opening Data as of Mar 29
# 2  Karnataka        KA   KA-P2         NaN  Opening Data as of Mar 29
# 3  Karnataka        KA   KA-P4         NaN  Opening Data as of Mar 29
# 4  Karnataka        KA  KA-P53         NaN  Opening Data as of Mar 29
#
#   Source_2 Source_3 Patient_Number (Could be mapped later)
# 0      NaN      NaN                                    P74
# ...

# %%
df_i_26a_rd = df_i_26a_rd[['Sl_No', 'Patient_Status']]

# %%
df_i_26a_rd.head()
# Out:
#    Sl_No Patient_Status
# 0     59       Deceased
# 1     54      Recovered
# 2     55      Recovered
# 3     56      Recovered
# 4     60       Deceased

# %%
df_i_26a_rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7407 entries, 0 to 7406
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sl_No           7407 non-null   int64
#  1   Patient_Status  7407 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 115.9+ KB

# %%
df_i_26a_rd.rename(columns = {'Sl_No': 'Patient Number'}, inplace = True)

# %%
df_i_26a_rd.head()
# Out:
#    Patient Number Patient_Status
# 0              59       Deceased
# 1              54      Recovered
# 2              55      Recovered
# 3              56      Recovered
# 4              60       Deceased

# %%
df_i_26a_all = df_i_26a_cc.merge(df_i_26a_rd,how='outer',left_on='Patient Number', right_on='Patient Number')

# %%
df_i_26a_all.head()
# Out:
#    Patient Number Date Announced Age Bracket Gender Detected District  \
# 0             1.0     30/01/2020          20      F          Thrissur
# 1             2.0     02/02/2020         NaN    NaN         Alappuzha
# 2             3.0     03/02/2020         NaN    NaN         Kasaragod
# 3             4.0     02/03/2020          45      M        East Delhi
# 4             5.0     02/03/2020          24      M         Hyderabad
#
#   Detected State State code Status Change Date Patient_Status
# 0         Kerala         KL         14/02/2020       Deceased
# 1         Kerala         KL         14/02/2020       Deceased
# 2         Kerala         KL         14/02/2020       Deceased
# 3          Delhi         DL         15/03/2020       Deceased
# 4      Telangana         TG         02/03/2020       Deceased

# %%
df_i_26a_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28183 entries, 0 to 28182
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient Number      27891 non-null  float64
#  1   Date Announced      28183 non-null  object
#  2   Age Bracket         2346 non-null   object
#  3   Gender              5313 non-null   object
#  4   Detected District   21198 non-null  object
#  5   Detected State      28182 non-null  object
#  6   State code          28182 non-null  object
#  7   Status Change Date  27780 non-null  object
#  8   Patient_Status      7407 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 2.2+ MB

# %%
df_27a_9m_all = pd.read_csv('confirmed, recovered and deceased cases from April 27th till May 9th.csv')

# %%
df_27a_9m_all.head()
# Out:
#    Entry_ID State Patient Number Date Announced  Age Bracket Gender  \
# 0         1                  NaN     27/04/2020          NaN    NaN
# 1         2                  NaN     27/04/2020          NaN    NaN
# 2         3                  NaN     27/04/2020          NaN    NaN
# 3         4                  NaN     27/04/2020         28.0      M
# 4         5                  NaN     27/04/2020          NaN    NaN
#
#   Detected City Detected District Detected State State code  Num Cases  \
# 0           NaN               NaN    West Bengal         WB       38.0
# 1           NaN          Bhilwara      Rajasthan         RJ        2.0
# 2           NaN            Jaipur      Rajasthan         RJ        9.0
# 3      Surajpol            Jaipur      Rajasthan         RJ        1.0
# 4           NaN         Jaisalmer      Rajasthan         RJ        1.0
#
#   Current Status Contracted from which Patient (Suspected)            Notes  \
# ...

# %%
df_27a_9m_all = df_27a_9m_all[['Patient Number', 'Date Announced', 'Age Bracket', 'Gender', 'Detected District', 'Detected State', 'State code', 'Status Change Date', 'Current Status']]

# %%
df_27a_9m_all.head()
# Out:
#    Patient Number Date Announced  Age Bracket Gender Detected District  \
# 0         27892.0     27/04/2020          NaN    NaN               NaN
# 1         27893.0     27/04/2020          NaN    NaN          Bhilwara
# 2         27894.0     27/04/2020          NaN    NaN            Jaipur
# 3         27895.0     27/04/2020         28.0      M            Jaipur
# 4         27896.0     27/04/2020          NaN    NaN         Jaisalmer
#
#   Detected State State code  Status Change Date Current Status
# 0    West Bengal         WB                 NaN   Hospitalized
# 1      Rajasthan         RJ                 NaN   Hospitalized
# 2      Rajasthan         RJ                 NaN   Hospitalized
# 3      Rajasthan         RJ                 NaN       Deceased
# 4      Rajasthan         RJ                 NaN   Hospitalized

# %%
df_27a_9m_all = df_27a_9m_all.rename(columns = {'Current Status' : 'Patient_Status'})

# %%
df_27a_9m_all.head()
# Out:
#    Patient Number Date Announced  Age Bracket Gender Detected District  \
# 0         27892.0     27/04/2020          NaN    NaN               NaN
# 1         27893.0     27/04/2020          NaN    NaN          Bhilwara
# 2         27894.0     27/04/2020          NaN    NaN            Jaipur
# 3         27895.0     27/04/2020         28.0      M            Jaipur
# 4         27896.0     27/04/2020          NaN    NaN         Jaisalmer
#
#   Detected State State code  Status Change Date Patient_Status
# 0    West Bengal         WB                 NaN   Hospitalized
# 1      Rajasthan         RJ                 NaN   Hospitalized
# 2      Rajasthan         RJ                 NaN   Hospitalized
# 3      Rajasthan         RJ                 NaN       Deceased
# 4      Rajasthan         RJ                 NaN   Hospitalized

# %%
df_27a_9m_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10020 entries, 0 to 10019
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient Number      10008 non-null  float64
#  1   Date Announced      10020 non-null  object
#  2   Age Bracket         5183 non-null   float64
#  3   Gender              4654 non-null   object
#  4   Detected District   9934 non-null   object
#  5   Detected State      10015 non-null  object
#  6   State code          10015 non-null  object
#  7   Status Change Date  0 non-null      float64
#  8   Patient_Status      10020 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 704.7+ KB

# %%
frames = [df_i_26a_all, df_27a_9m_all]

# %%
df_i_9m_all = pd.concat(frames)

# %%
df_i_9m_all
# Out:
#        Patient Number Date Announced Age Bracket Gender Detected District  \
# 0                 1.0     30/01/2020          20      F          Thrissur
# 1                 2.0     02/02/2020         NaN    NaN         Alappuzha
# 2                 3.0     03/02/2020         NaN    NaN         Kasaragod
# 3                 4.0     02/03/2020          45      M        East Delhi
# 4                 5.0     02/03/2020          24      M         Hyderabad
# ...               ...            ...         ...    ...               ...
# 10015             NaN     27/04/2020         NaN    NaN      Thoothukkudi
# 10016             NaN     27/04/2020         NaN    NaN               NaN
# 10017             NaN     14/03/2020         NaN    NaN               NaN
# 10018             NaN     14/03/2020         NaN    NaN               NaN
# 10019             NaN     14/03/2020         NaN    NaN               NaN
#
#          Detected State State code Status Change Date  Patient_Status
# ...

# %%
df_i_9m_all = df_i_9m_all.reset_index()

# %%
df_i_9m_all = df_i_9m_all.drop(['index'] , axis=1)

# %%
df_i_9m_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38203 entries, 0 to 38202
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient Number      37899 non-null  float64
#  1   Date Announced      38203 non-null  object
#  2   Age Bracket         7529 non-null   object
#  3   Gender              9967 non-null   object
#  4   Detected District   31132 non-null  object
#  5   Detected State      38197 non-null  object
#  6   State code          38197 non-null  object
#  7   Status Change Date  27780 non-null  object
#  8   Patient_Status      17427 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 2.6+ MB

# %%
df_i_9m_all.head()
# Out:
#    Patient Number Date Announced Age Bracket Gender Detected District  \
# 0             1.0     30/01/2020          20      F          Thrissur
# 1             2.0     02/02/2020         NaN    NaN         Alappuzha
# 2             3.0     03/02/2020         NaN    NaN         Kasaragod
# 3             4.0     02/03/2020          45      M        East Delhi
# 4             5.0     02/03/2020          24      M         Hyderabad
#
#   Detected State State code Status Change Date Patient_Status
# 0         Kerala         KL         14/02/2020       Deceased
# 1         Kerala         KL         14/02/2020       Deceased
# 2         Kerala         KL         14/02/2020       Deceased
# 3          Delhi         DL         15/03/2020       Deceased
# 4      Telangana         TG         02/03/2020       Deceased

# %%
df_10m_23m_all = pd.read_csv('confirmed, recovered and deceased cases from May 10th till May 23rd.csv')

# %%
df_10m_23m_all = df_10m_23m_all[['Patient Number', 'Date Announced', 'Age Bracket', 'Gender', 'Detected District', 'Detected State', 'State code', 'Status Change Date', 'Current Status']]

# %%
df_10m_23m_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18220 entries, 0 to 18219
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient Number      18212 non-null  float64
#  1   Date Announced      18220 non-null  object
#  2   Age Bracket         11857 non-null  float64
#  3   Gender              11969 non-null  object
#  4   Detected District   18033 non-null  object
#  5   Detected State      18220 non-null  object
#  6   State code          18220 non-null  object
#  7   Status Change Date  0 non-null      float64
#  8   Current Status      18218 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 1.3+ MB

# %%
df_10m_23m_all.head()
# Out:
#    Patient Number Date Announced  Age Bracket Gender Detected District  \
# 0         37900.0     10/05/2020          NaN    NaN             Ajmer
# 1         37901.0     10/05/2020          NaN    NaN         Dungarpur
# 2         37902.0     10/05/2020          NaN    NaN            Jaipur
# 3         37903.0     10/05/2020          NaN    NaN              Kota
# 4         37904.0     10/05/2020          NaN    NaN              Pali
#
#   Detected State State code  Status Change Date Current Status
# 0      Rajasthan         RJ                 NaN   Hospitalized
# 1      Rajasthan         RJ                 NaN   Hospitalized
# 2      Rajasthan         RJ                 NaN   Hospitalized
# 3      Rajasthan         RJ                 NaN   Hospitalized
# 4      Rajasthan         RJ                 NaN   Hospitalized

# %%
df_24m_4j_all = pd.read_csv('confirmed, recovered and deceased cases from May 24th till June 4th.csv')

# %%
df_24m_4j_all = df_24m_4j_all[['Patient Number', 'Date Announced', 'Age Bracket', 'Gender', 'Detected District', 'Detected State', 'State code', 'Status Change Date', 'Current Status']]

# %%
df_24m_4j_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20438 entries, 0 to 20437
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient Number      20259 non-null  float64
#  1   Date Announced      20438 non-null  object
#  2   Age Bracket         11365 non-null  float64
#  3   Gender              11472 non-null  object
#  4   Detected District   20184 non-null  object
#  5   Detected State      20436 non-null  object
#  6   State code          20436 non-null  object
#  7   Status Change Date  0 non-null      float64
#  8   Current Status      20438 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 1.4+ MB

# %%
df_24m_4j_all.head()
# Out:
#    Patient Number Date Announced  Age Bracket Gender Detected District  \
# 0         57292.0     23/05/2020          NaN    NaN               NaN
# 1         57159.0     24/05/2020          NaN    NaN        Unassigned
# 2         57160.0     24/05/2020          NaN    NaN            Ganjam
# 3         57161.0     24/05/2020          NaN    NaN              Puri
# 4         57162.0     24/05/2020          NaN    NaN           Khordha
#
#      Detected State State code  Status Change Date Current Status
# 0           Manipur         MN                 NaN   Hospitalized
# 1  State Unassigned         UN                 NaN   Hospitalized
# 2            Odisha         OR                 NaN   Hospitalized
# 3            Odisha         OR                 NaN   Hospitalized
# 4            Odisha         OR                 NaN   Hospitalized

# %%
df_5j_19j_all = pd.read_csv('confirmed, recovered and deceased cases from June 5th till June 19th.csv')

# %%
df_5j_19j_all = df_5j_19j_all[['Patient Number', 'Date Announced', 'Age Bracket', 'Gender', 'Detected District', 'Detected State', 'State code', 'Status Change Date', 'Current Status']]

# %%
frames = [df_i_9m_all, df_10m_23m_all, df_24m_4j_all, df_5j_19j_all]

# %%
df_i_19j_all = pd.concat(frames)

# %%
df_i_19j_all = df_i_19j_all.reset_index()

# %%
df_i_19j_all = df_i_19j_all.drop(['index'], axis = 1)

# %%
df_i_19j_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100284 entries, 0 to 100283
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Patient Number      99793 non-null   float64
#  1   Date Announced      100284 non-null  object
#  2   Age Bracket         37841 non-null   object
#  3   Gender              40548 non-null   object
#  4   Detected District   92399 non-null   object
#  5   Detected State      100275 non-null  object
#  6   State code          100275 non-null  object
#  7   Status Change Date  27780 non-null   object
#  8   Patient_Status      17427 non-null   object
#  9   Current Status      62079 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 7.7+ MB

# %%
df_i_19j_all.isnull().sum()
# Out:
# Patient Number          491
# Date Announced            0
# Age Bracket           62443
# Gender                59736
# Detected District      7885
# Detected State            9
# State code                9
# Status Change Date    72504
# Patient_Status        82857
# Current Status        38205
# dtype: int64

# %%
df_20j_30j = pd.read_csv('jun20 to jun 30.csv')

# %%
df_1jl_7jl = pd.read_csv('jul1 to jul7.csv')

# %%
df_8jl_13jl = pd.read_csv('jul8 to jul13.csv')

# %%
df_14jl_17jl = pd.read_csv('jul14 to jul17.csv')

# %%
df_18jl_22jl = pd.read_csv('jul18 to jul 22.csv')

# %%
df_23jl_28jl = pd.read_csv('jul23 to jul28.csv')

# %%
frames = [df_20j_30j, df_1jl_7jl, df_8jl_13jl, df_14jl_17jl, df_18jl_22jl, df_23jl_28jl]

# %%
df_20j_28jl = pd.concat(frames)

# %%
df_20j_28jl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133841 entries, 0 to 9225
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Entry_ID                                   133841 non-null  int64
#  1   State Patient Number                       86756 non-null   object
#  2   Date Announced                             133530 non-null  object
#  3   Age Bracket                                68902 non-null   object
#  4   Gender                                     68977 non-null   object
#  5   Detected City                              3721 non-null    object
#  6   Detected District                          132192 non-null  object
#  7   Detected State                             133248 non-null  object
#  8   State code                                 133248 non-null  object
# ...
